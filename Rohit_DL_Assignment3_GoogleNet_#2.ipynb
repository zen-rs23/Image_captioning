# %%
# Connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import json
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from collections import Counter
from tqdm.notebook import tqdm
import random
import warnings

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from nltk.translate.bleu_score import sentence_bleu
import torchvision.transforms.functional as F

# %%
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
import zipfile

# Unzipping Flickr8k_Dataset.zip
with zipfile.ZipFile('/content/drive/MyDrive/Flickr8k_Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Flickr8k_Dataset')

# Unzipping Flickr8k_text.zip
with zipfile.ZipFile('/content/drive/MyDrive/Flickr8k_text.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Flickr8k_text')

# %%
# Paths
image_dir = '/content/Flickr8k_Dataset/Flicker8k_Dataset'
annotations_file = '/content/Flickr8k_text/Flickr8k.token.txt'
train_file = '/content/Flickr8k_text/Flickr_8k.trainImages.txt'
val_file = '/content/Flickr8k_text/Flickr_8k.devImages.txt'
test_file = '/content/Flickr8k_text/Flickr_8k.testImages.txt'

# Read annotations
with open(annotations_file, 'r') as f:
    annotations = f.readlines()

# Create a dictionary for image captions
captions_dict = {}
for line in annotations:
    img_name, caption = line.strip().split('\t')
    img_name = img_name.split('#')[0]
    if img_name not in captions_dict:
        captions_dict[img_name] = []
    captions_dict[img_name].append(caption)

# Load train, val, and test image names
def load_image_names(file_path):
    with open(file_path, 'r') as f:
        return f.read().strip().split('\n')

train_img_names = load_image_names(train_file)
val_img_names = load_image_names(val_file)
test_img_names = load_image_names(test_file)

# %%
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def __call__(self, word):
        return self.word2idx.get(word, self.word2idx['<unk>'])

    def __len__(self):
        return len(self.word2idx)

# %%
# Initialize vocabulary
vocab = Vocabulary()

# Add special tokens
special_tokens = ['<pad>', '<start>', '<end>', '<unk>']
for token in special_tokens:
    vocab.add_word(token)

# Tokenize and add words to the vocabulary
for img_name, captions in captions_dict.items():
    for caption in captions:
        tokens = caption.split()  # Simple whitespace tokenizer
        for token in tokens:
            vocab.add_word(token)

print(f"Vocabulary size: {len(vocab)}")
# Out:
# Vocabulary size: 9634

# %%
# Sample a percentage of the training and validation data
def sample_data(img_names, percentage):
    sample_size = int(len(img_names) * percentage)
    return random.sample(img_names, sample_size)

train_img_names_sampled = sample_data(train_img_names, 0.5)  # Sample 50% of images for training
val_img_names_sampled = sample_data(val_img_names, 0.5)  # Sample 50% of images for validation

# Use the full dataset
#train_img_names_sampled = train_img_names  # Use all images for training
#val_img_names_sampled = val_img_names  # Use all images for validation

# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Define collate_fn function
def collate_fn(data):
    images, captions = zip(*data)
    images = torch.stack(images, 0)

    # Tokenize captions and convert to indices
    tokenizer = lambda x: x.split()  # Simple whitespace tokenizer
    captions = [[vocab(token) for token in tokenizer(caption)] for caption in captions]

    # Find the length of the longest caption
    max_len = max(len(caption) for caption in captions)

    # Pad all captions to the same length
    padded_captions = []
    for caption in captions:
        padded_caption = caption + [vocab('<pad>')] * (max_len - len(caption))
        padded_captions.append(padded_caption)

    # Convert to tensor
    captions = torch.tensor(padded_captions)

    return images, captions

class Flickr8kDataset(Dataset):
    def __init__(self, img_names, captions_dict, img_dir, transform=None):
        self.img_names = img_names
        self.captions_dict = captions_dict
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_name = self.img_names[idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        caption = random.choice(self.captions_dict[img_name])  # Choose a random caption for the image
        return image, caption

# Create dataset objects
train_dataset = Flickr8kDataset(train_img_names_sampled, captions_dict, image_dir, transform)
val_dataset = Flickr8kDataset(val_img_names_sampled, captions_dict, image_dir, transform)
test_dataset = Flickr8kDataset(test_img_names, captions_dict, image_dir, transform)

# Create data loaders with collate_fn
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, collate_fn=collate_fn)

# %%
# Check if GPU is available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class EncoderCNN(nn.Module):
    def __init__(self, embed_size):
        super(EncoderCNN, self).__init__()
        googlenet = models.googlenet(pretrained=True)
        for param in googlenet.parameters():
            param.requires_grad = False
        self.googlenet = nn.Sequential(*list(googlenet.children())[:-2])
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.linear = nn.Linear(googlenet.fc.in_features, embed_size)
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.01)

    def forward(self, images):
        features = self.googlenet(images)
        features = self.adaptive_pool(features).reshape(features.size(0), -1)
        features = self.bn(self.linear(features))
        return features


class DecoderRNN(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers=1):
        super(DecoderRNN, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, features, captions):
        embeddings = self.embed(captions)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)
        hiddens, _ = self.lstm(embeddings)
        outputs = self.linear(hiddens)
        return outputs

    def sample(self, features, states=None, max_len=20):
        """Generate captions for given image features using greedy search."""
        sampled_ids = []
        inputs = features.unsqueeze(1)
        batch_size = features.size(0)
        for i in range(max_len):
            hiddens, states = self.lstm(inputs, states)  # hiddens: (batch_size, 1, hidden_size)
            outputs = self.linear(hiddens.squeeze(1))  # outputs: (batch_size, vocab_size)
            _, predicted = outputs.max(1)  # predicted: (batch_size)
            sampled_ids.append(predicted)
            inputs = self.embed(predicted)  # inputs: (batch_size, embed_size)
            inputs = inputs.unsqueeze(1)  # inputs: (batch_size, 1, embed_size)
            if (predicted == vocab('<end>')).all():  # Stop if all predictions in the batch are <end>
                break
        sampled_ids = torch.stack(sampled_ids, 1)  # sampled_ids: (batch_size, max_seq_length)
        return sampled_ids

# Instantiate encoder and decoder
embed_size = 256
hidden_size = 512
vocab_size = len(vocab)  # Update based on your vocabulary size

encoder = EncoderCNN(embed_size).to(device)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size).to(device)

# %%
def generate_captions(encoder, decoder, data_loader, vocab, max_length=20):
    encoder.eval()
    decoder.eval()
    all_images = []
    all_captions = []

    with torch.no_grad():
        for images, _ in data_loader:
            images = images.to(device)
            features = encoder(images)
            sampled_ids = decoder.sample(features, max_len=max_length)
            sampled_ids = sampled_ids.cpu().numpy()

            for i, image in enumerate(images):
                all_images.append(image.cpu())
                caption = []
                for word_id in sampled_ids[i]:
                    word = vocab.idx2word[word_id]
                    if word == '<end>':
                        break
                    if word != '<pad>':
                        caption.append(word)
                caption = ' '.join(caption)
                all_captions.append(caption)

    return all_images, all_captions

def visualize_captions(images, captions, num_samples=5):
    num_samples = min(num_samples, len(images))  # Ensure num_samples does not exceed available images
    plt.figure(figsize=(15, 15))

    for i in range(num_samples):
        plt.subplot((num_samples + 1) // 2, 2, i + 1)
        image = images[i]
        if isinstance(image, torch.Tensor):
            print(f"Original image shape: {image.shape}")
            image = image.permute(1, 2, 0)  # Change from (C, H, W) to (H, W, C)
            print(f"Permuted image shape: {image.shape}")
            image = image.numpy()
            print(f"Numpy image shape: {image.shape}")
            image = transforms.ToPILImage()(image)
            print(f"Converted image type: {type(image)}")
        plt.imshow(image)
        plt.title(captions[i])
        plt.axis('off')
    plt.show()

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.bn.parameters())
optimizer = optim.Adam(params, lr=0.001)

# %%
# Training loop
num_epochs = 20
log_step = 5

for epoch in range(num_epochs):
    encoder.train()
    decoder.train()
    for i, (images, captions) in enumerate(train_loader):
        images = images.to(device)
        captions = captions.to(device)

        features = encoder(images)
        outputs = decoder(features, captions)

        batch_size, sequence_length, _ = outputs.shape
        targets = captions[:, 1:]

        if targets.shape[1] < sequence_length:
            padding = torch.full((batch_size, sequence_length - targets.shape[1]), vocab('<pad>')).to(device)
            targets = torch.cat((targets, padding), dim=1)
        elif targets.shape[1] > sequence_length:
            targets = targets[:, :sequence_length]

        loss = criterion(outputs.view(batch_size * sequence_length, -1), targets.reshape(-1))

        decoder.zero_grad()
        encoder.zero_grad()
        loss.backward()
        optimizer.step()

        if i % log_step == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i}/{len(train_loader)}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/20], Step [0/94], Loss: 9.2285
# Epoch [1/20], Step [5/94], Loss: 5.7283
# Epoch [1/20], Step [10/94], Loss: 5.1414
# Epoch [1/20], Step [15/94], Loss: 3.3874
# Epoch [1/20], Step [20/94], Loss: 3.4838
# Epoch [1/20], Step [25/94], Loss: 3.2882
# Epoch [1/20], Step [30/94], Loss: 2.9193
# Epoch [1/20], Step [35/94], Loss: 3.3817
# Epoch [1/20], Step [40/94], Loss: 3.2905
# Epoch [1/20], Step [45/94], Loss: 1.9004
# Epoch [1/20], Step [50/94], Loss: 2.5420
# Epoch [1/20], Step [55/94], Loss: 2.1467
# Epoch [1/20], Step [60/94], Loss: 3.1446
# Epoch [1/20], Step [65/94], Loss: 2.6355
# Epoch [1/20], Step [70/94], Loss: 3.1944
# Epoch [1/20], Step [75/94], Loss: 3.3087
# Epoch [1/20], Step [80/94], Loss: 3.2885
# Epoch [1/20], Step [85/94], Loss: 3.3333
# Epoch [1/20], Step [90/94], Loss: 3.1408
# Epoch [2/20], Step [0/94], Loss: 2.3882
# Epoch [2/20], Step [5/94], Loss: 3.1982
# Epoch [2/20], Step [10/94], Loss: 2.4885
# Epoch [2/20], Step [15/94], Loss: 2.7175
# Epoch [2/20], Step [20/94], Loss: 2.0054
# Epoch [2/20], Step [25/94], Loss: 2.4129
# Epoch [2/20], Step [30/94], Loss: 2.4970
# Epoch [2/20], Step [35/94], Loss: 2.2145
# Epoch [2/20], Step [40/94], Loss: 2.8983
# Epoch [2/20], Step [45/94], Loss: 2.3721
# Epoch [2/20], Step [50/94], Loss: 2.9037
# Epoch [2/20], Step [55/94], Loss: 2.8075
# Epoch [2/20], Step [60/94], Loss: 2.4202
# Epoch [2/20], Step [65/94], Loss: 2.2620
# Epoch [2/20], Step [70/94], Loss: 2.3794
# Epoch [2/20], Step [75/94], Loss: 2.3790
# Epoch [2/20], Step [80/94], Loss: 2.5486
# Epoch [2/20], Step [85/94], Loss: 2.6019
# Epoch [2/20], Step [90/94], Loss: 2.5117
# Epoch [3/20], Step [0/94], Loss: 2.7322
# Epoch [3/20], Step [5/94], Loss: 2.5264
# Epoch [3/20], Step [10/94], Loss: 2.1037
# Epoch [3/20], Step [15/94], Loss: 2.4878
# Epoch [3/20], Step [20/94], Loss: 2.6959
# Epoch [3/20], Step [25/94], Loss: 2.5636
# Epoch [3/20], Step [30/94], Loss: 2.8282
# Epoch [3/20], Step [35/94], Loss: 1.7884
# Epoch [3/20], Step [40/94], Loss: 2.7431
# Epoch [3/20], Step [45/94], Loss: 2.3866
# Epoch [3/20], Step [50/94], Loss: 2.6915
# Epoch [3/20], Step [55/94], Loss: 2.1310
# Epoch [3/20], Step [60/94], Loss: 2.4196
# Epoch [3/20], Step [65/94], Loss: 2.0773
# Epoch [3/20], Step [70/94], Loss: 2.3456
# Epoch [3/20], Step [75/94], Loss: 2.1897
# Epoch [3/20], Step [80/94], Loss: 2.3786
# Epoch [3/20], Step [85/94], Loss: 2.6556
# Epoch [3/20], Step [90/94], Loss: 2.3774
# Epoch [4/20], Step [0/94], Loss: 2.0152
# Epoch [4/20], Step [5/94], Loss: 2.6169
# Epoch [4/20], Step [10/94], Loss: 1.7368
# Epoch [4/20], Step [15/94], Loss: 2.2618
# Epoch [4/20], Step [20/94], Loss: 2.6741
# Epoch [4/20], Step [25/94], Loss: 2.1826
# Epoch [4/20], Step [30/94], Loss: 2.4137
# Epoch [4/20], Step [35/94], Loss: 2.4687
# Epoch [4/20], Step [40/94], Loss: 2.2437
# Epoch [4/20], Step [45/94], Loss: 1.9163
# Epoch [4/20], Step [50/94], Loss: 2.0778
# Epoch [4/20], Step [55/94], Loss: 2.2900
# Epoch [4/20], Step [60/94], Loss: 2.0173
# Epoch [4/20], Step [65/94], Loss: 2.1286
# Epoch [4/20], Step [70/94], Loss: 2.4714
# Epoch [4/20], Step [75/94], Loss: 1.9797
# Epoch [4/20], Step [80/94], Loss: 2.6970
# Epoch [4/20], Step [85/94], Loss: 2.6668
# Epoch [4/20], Step [90/94], Loss: 2.2209
# Epoch [5/20], Step [0/94], Loss: 2.4642
# Epoch [5/20], Step [5/94], Loss: 2.5859
# Epoch [5/20], Step [10/94], Loss: 2.1316
# Epoch [5/20], Step [15/94], Loss: 2.1950
# Epoch [5/20], Step [20/94], Loss: 2.1443
# Epoch [5/20], Step [25/94], Loss: 2.7228
# Epoch [5/20], Step [30/94], Loss: 2.2066
# Epoch [5/20], Step [35/94], Loss: 2.0770
# Epoch [5/20], Step [40/94], Loss: 2.1276
# Epoch [5/20], Step [45/94], Loss: 2.3796
# Epoch [5/20], Step [50/94], Loss: 2.5069
# Epoch [5/20], Step [55/94], Loss: 2.7830
# Epoch [5/20], Step [60/94], Loss: 2.0256
# Epoch [5/20], Step [65/94], Loss: 2.5415
# Epoch [5/20], Step [70/94], Loss: 2.2317
# Epoch [5/20], Step [75/94], Loss: 2.0535
# Epoch [5/20], Step [80/94], Loss: 2.1753
# Epoch [5/20], Step [85/94], Loss: 2.3353
# Epoch [5/20], Step [90/94], Loss: 2.2508
# Epoch [6/20], Step [0/94], Loss: 2.2456
# Epoch [6/20], Step [5/94], Loss: 2.2411
# Epoch [6/20], Step [10/94], Loss: 2.0657
# Epoch [6/20], Step [15/94], Loss: 2.6128
# Epoch [6/20], Step [20/94], Loss: 2.3189
# Epoch [6/20], Step [25/94], Loss: 1.9604
# Epoch [6/20], Step [30/94], Loss: 1.9513
# Epoch [6/20], Step [35/94], Loss: 2.2170
# Epoch [6/20], Step [40/94], Loss: 1.8788
# Epoch [6/20], Step [45/94], Loss: 1.7612
# Epoch [6/20], Step [50/94], Loss: 2.5725
# Epoch [6/20], Step [55/94], Loss: 2.4097
# Epoch [6/20], Step [60/94], Loss: 2.6444
# Epoch [6/20], Step [65/94], Loss: 1.9330
# Epoch [6/20], Step [70/94], Loss: 2.0786
# Epoch [6/20], Step [75/94], Loss: 2.4717
# Epoch [6/20], Step [80/94], Loss: 2.1128
# Epoch [6/20], Step [85/94], Loss: 2.0001
# Epoch [6/20], Step [90/94], Loss: 2.4072
# Epoch [7/20], Step [0/94], Loss: 2.1641
# Epoch [7/20], Step [5/94], Loss: 2.2896
# Epoch [7/20], Step [10/94], Loss: 2.0837
# Epoch [7/20], Step [15/94], Loss: 2.2509
# Epoch [7/20], Step [20/94], Loss: 2.1865
# Epoch [7/20], Step [25/94], Loss: 2.3037
# Epoch [7/20], Step [30/94], Loss: 2.3274
# Epoch [7/20], Step [35/94], Loss: 1.6603
# Epoch [7/20], Step [40/94], Loss: 1.7362
# Epoch [7/20], Step [45/94], Loss: 2.0185
# Epoch [7/20], Step [50/94], Loss: 2.2952
# Epoch [7/20], Step [55/94], Loss: 1.9142
# Epoch [7/20], Step [60/94], Loss: 2.1419
# Epoch [7/20], Step [65/94], Loss: 1.7245
# Epoch [7/20], Step [70/94], Loss: 2.3201
# Epoch [7/20], Step [75/94], Loss: 2.2879
# Epoch [7/20], Step [80/94], Loss: 2.3459
# Epoch [7/20], Step [85/94], Loss: 1.9546
# Epoch [7/20], Step [90/94], Loss: 2.6364
# Epoch [8/20], Step [0/94], Loss: 2.3015
# Epoch [8/20], Step [5/94], Loss: 2.4498
# Epoch [8/20], Step [10/94], Loss: 1.8793
# Epoch [8/20], Step [15/94], Loss: 2.3861
# Epoch [8/20], Step [20/94], Loss: 2.0030
# Epoch [8/20], Step [25/94], Loss: 2.0749
# Epoch [8/20], Step [30/94], Loss: 2.4127
# Epoch [8/20], Step [35/94], Loss: 1.9282
# Epoch [8/20], Step [40/94], Loss: 2.3044
# Epoch [8/20], Step [45/94], Loss: 1.7683
# Epoch [8/20], Step [50/94], Loss: 2.1571
# Epoch [8/20], Step [55/94], Loss: 1.7446
# Epoch [8/20], Step [60/94], Loss: 2.0859
# Epoch [8/20], Step [65/94], Loss: 1.8675
# Epoch [8/20], Step [70/94], Loss: 2.0031
# Epoch [8/20], Step [75/94], Loss: 2.4591
# Epoch [8/20], Step [80/94], Loss: 2.3609
# Epoch [8/20], Step [85/94], Loss: 2.1961
# Epoch [8/20], Step [90/94], Loss: 2.0329
# Epoch [9/20], Step [0/94], Loss: 2.6070
# Epoch [9/20], Step [5/94], Loss: 2.1545
# Epoch [9/20], Step [10/94], Loss: 2.0911
# Epoch [9/20], Step [15/94], Loss: 2.0596
# Epoch [9/20], Step [20/94], Loss: 2.1398
# Epoch [9/20], Step [25/94], Loss: 2.0839
# Epoch [9/20], Step [30/94], Loss: 2.0714
# Epoch [9/20], Step [35/94], Loss: 2.0832
# Epoch [9/20], Step [40/94], Loss: 2.0476
# Epoch [9/20], Step [45/94], Loss: 2.2180
# Epoch [9/20], Step [50/94], Loss: 2.2659
# Epoch [9/20], Step [55/94], Loss: 2.0635
# Epoch [9/20], Step [60/94], Loss: 2.1767
# Epoch [9/20], Step [65/94], Loss: 1.8196
# Epoch [9/20], Step [70/94], Loss: 1.9861
# Epoch [9/20], Step [75/94], Loss: 2.2065
# Epoch [9/20], Step [80/94], Loss: 2.0535
# Epoch [9/20], Step [85/94], Loss: 2.4798
# Epoch [9/20], Step [90/94], Loss: 2.2039
# Epoch [10/20], Step [0/94], Loss: 2.0964
# Epoch [10/20], Step [5/94], Loss: 2.2140
# Epoch [10/20], Step [10/94], Loss: 2.0479
# Epoch [10/20], Step [15/94], Loss: 2.2053
# Epoch [10/20], Step [20/94], Loss: 1.7939
# Epoch [10/20], Step [25/94], Loss: 1.9854
# Epoch [10/20], Step [30/94], Loss: 1.8705
# Epoch [10/20], Step [35/94], Loss: 2.1090
# Epoch [10/20], Step [40/94], Loss: 2.2530
# Epoch [10/20], Step [45/94], Loss: 2.0363
# Epoch [10/20], Step [50/94], Loss: 1.8907
# Epoch [10/20], Step [55/94], Loss: 2.0912
# Epoch [10/20], Step [60/94], Loss: 2.1132
# Epoch [10/20], Step [65/94], Loss: 1.9024
# Epoch [10/20], Step [70/94], Loss: 1.9597
# Epoch [10/20], Step [75/94], Loss: 2.0477
# Epoch [10/20], Step [80/94], Loss: 2.2965
# Epoch [10/20], Step [85/94], Loss: 2.1204
# Epoch [10/20], Step [90/94], Loss: 1.7102
# Epoch [11/20], Step [0/94], Loss: 2.1423
# Epoch [11/20], Step [5/94], Loss: 1.7585
# Epoch [11/20], Step [10/94], Loss: 1.8189
# Epoch [11/20], Step [15/94], Loss: 2.0083
# Epoch [11/20], Step [20/94], Loss: 2.0022
# Epoch [11/20], Step [25/94], Loss: 2.1092
# Epoch [11/20], Step [30/94], Loss: 2.2590
# Epoch [11/20], Step [35/94], Loss: 1.8297
# Epoch [11/20], Step [40/94], Loss: 1.9461
# Epoch [11/20], Step [45/94], Loss: 2.1080
# Epoch [11/20], Step [50/94], Loss: 2.0508
# Epoch [11/20], Step [55/94], Loss: 2.1302
# Epoch [11/20], Step [60/94], Loss: 2.1334
# Epoch [11/20], Step [65/94], Loss: 1.7850
# Epoch [11/20], Step [70/94], Loss: 1.8392
# Epoch [11/20], Step [75/94], Loss: 1.5168
# Epoch [11/20], Step [80/94], Loss: 2.0011
# Epoch [11/20], Step [85/94], Loss: 2.0497
# Epoch [11/20], Step [90/94], Loss: 1.8793
# Epoch [12/20], Step [0/94], Loss: 1.8181
# Epoch [12/20], Step [5/94], Loss: 1.9295
# Epoch [12/20], Step [10/94], Loss: 1.9273
# Epoch [12/20], Step [15/94], Loss: 1.7322
# Epoch [12/20], Step [20/94], Loss: 1.5237
# Epoch [12/20], Step [25/94], Loss: 2.1939
# Epoch [12/20], Step [30/94], Loss: 2.0141
# Epoch [12/20], Step [35/94], Loss: 2.0127
# Epoch [12/20], Step [40/94], Loss: 1.7625
# Epoch [12/20], Step [45/94], Loss: 2.0359
# Epoch [12/20], Step [50/94], Loss: 2.3128
# Epoch [12/20], Step [55/94], Loss: 1.7808
# Epoch [12/20], Step [60/94], Loss: 1.8526
# Epoch [12/20], Step [65/94], Loss: 1.8599
# Epoch [12/20], Step [70/94], Loss: 1.8382
# Epoch [12/20], Step [75/94], Loss: 2.0010
# Epoch [12/20], Step [80/94], Loss: 2.1858
# Epoch [12/20], Step [85/94], Loss: 1.6284
# Epoch [12/20], Step [90/94], Loss: 1.9882
# Epoch [13/20], Step [0/94], Loss: 1.8683
# Epoch [13/20], Step [5/94], Loss: 1.5996
# Epoch [13/20], Step [10/94], Loss: 2.2056
# Epoch [13/20], Step [15/94], Loss: 1.8455
# Epoch [13/20], Step [20/94], Loss: 1.7973
# Epoch [13/20], Step [25/94], Loss: 1.5281
# Epoch [13/20], Step [30/94], Loss: 1.7571
# Epoch [13/20], Step [35/94], Loss: 1.9454
# Epoch [13/20], Step [40/94], Loss: 1.8761
# Epoch [13/20], Step [45/94], Loss: 1.7682
# Epoch [13/20], Step [50/94], Loss: 1.8734
# Epoch [13/20], Step [55/94], Loss: 2.0609
# Epoch [13/20], Step [60/94], Loss: 1.7315
# Epoch [13/20], Step [65/94], Loss: 1.9590
# Epoch [13/20], Step [70/94], Loss: 1.5128
# Epoch [13/20], Step [75/94], Loss: 1.7898
# Epoch [13/20], Step [80/94], Loss: 1.7251
# Epoch [13/20], Step [85/94], Loss: 2.0147
# Epoch [13/20], Step [90/94], Loss: 1.8169
# Epoch [14/20], Step [0/94], Loss: 1.9593
# Epoch [14/20], Step [5/94], Loss: 1.6904
# Epoch [14/20], Step [10/94], Loss: 1.7820
# Epoch [14/20], Step [15/94], Loss: 1.6128
# Epoch [14/20], Step [20/94], Loss: 1.6935
# Epoch [14/20], Step [25/94], Loss: 1.6304
# Epoch [14/20], Step [30/94], Loss: 1.2710
# Epoch [14/20], Step [35/94], Loss: 2.1175
# Epoch [14/20], Step [40/94], Loss: 1.9850
# Epoch [14/20], Step [45/94], Loss: 1.7472
# Epoch [14/20], Step [50/94], Loss: 1.8476
# Epoch [14/20], Step [55/94], Loss: 1.4682
# Epoch [14/20], Step [60/94], Loss: 1.9157
# Epoch [14/20], Step [65/94], Loss: 1.4091
# Epoch [14/20], Step [70/94], Loss: 1.6074
# Epoch [14/20], Step [75/94], Loss: 2.2643
# Epoch [14/20], Step [80/94], Loss: 1.9819
# Epoch [14/20], Step [85/94], Loss: 2.0274
# Epoch [14/20], Step [90/94], Loss: 2.0299
# Epoch [15/20], Step [0/94], Loss: 1.5232
# Epoch [15/20], Step [5/94], Loss: 1.8669
# Epoch [15/20], Step [10/94], Loss: 1.7146
# Epoch [15/20], Step [15/94], Loss: 1.7249
# Epoch [15/20], Step [20/94], Loss: 1.6576
# Epoch [15/20], Step [25/94], Loss: 1.8761
# Epoch [15/20], Step [30/94], Loss: 1.9362
# Epoch [15/20], Step [35/94], Loss: 2.1565
# Epoch [15/20], Step [40/94], Loss: 1.9973
# Epoch [15/20], Step [45/94], Loss: 2.2280
# Epoch [15/20], Step [50/94], Loss: 1.7268
# Epoch [15/20], Step [55/94], Loss: 1.6195
# Epoch [15/20], Step [60/94], Loss: 1.6593
# Epoch [15/20], Step [65/94], Loss: 1.9836
# Epoch [15/20], Step [70/94], Loss: 1.8010
# Epoch [15/20], Step [75/94], Loss: 1.9613
# Epoch [15/20], Step [80/94], Loss: 1.9330
# Epoch [15/20], Step [85/94], Loss: 1.8315
# Epoch [15/20], Step [90/94], Loss: 1.7647
# Epoch [16/20], Step [0/94], Loss: 1.5964
# Epoch [16/20], Step [5/94], Loss: 1.5507
# Epoch [16/20], Step [10/94], Loss: 1.9904
# Epoch [16/20], Step [15/94], Loss: 1.6268
# Epoch [16/20], Step [20/94], Loss: 1.5500
# Epoch [16/20], Step [25/94], Loss: 1.9147
# Epoch [16/20], Step [30/94], Loss: 1.9029
# Epoch [16/20], Step [35/94], Loss: 1.6079
# Epoch [16/20], Step [40/94], Loss: 1.7969
# Epoch [16/20], Step [45/94], Loss: 1.4197
# Epoch [16/20], Step [50/94], Loss: 1.9651
# Epoch [16/20], Step [55/94], Loss: 1.9701
# Epoch [16/20], Step [60/94], Loss: 1.4354
# Epoch [16/20], Step [65/94], Loss: 1.6871
# Epoch [16/20], Step [70/94], Loss: 1.8663
# Epoch [16/20], Step [75/94], Loss: 1.9707
# Epoch [16/20], Step [80/94], Loss: 1.5796
# Epoch [16/20], Step [85/94], Loss: 1.2062
# Epoch [16/20], Step [90/94], Loss: 1.6127
# Epoch [17/20], Step [0/94], Loss: 1.8556
# Epoch [17/20], Step [5/94], Loss: 1.7038
# Epoch [17/20], Step [10/94], Loss: 2.0046
# Epoch [17/20], Step [15/94], Loss: 1.5738
# Epoch [17/20], Step [20/94], Loss: 1.6964
# Epoch [17/20], Step [25/94], Loss: 1.7872
# Epoch [17/20], Step [30/94], Loss: 1.6199
# Epoch [17/20], Step [35/94], Loss: 1.6562
# Epoch [17/20], Step [40/94], Loss: 1.6513
# Epoch [17/20], Step [45/94], Loss: 1.2991
# Epoch [17/20], Step [50/94], Loss: 1.6899
# Epoch [17/20], Step [55/94], Loss: 1.6339
# Epoch [17/20], Step [60/94], Loss: 1.6876
# Epoch [17/20], Step [65/94], Loss: 1.3404
# Epoch [17/20], Step [70/94], Loss: 1.9338
# Epoch [17/20], Step [75/94], Loss: 1.7990
# Epoch [17/20], Step [80/94], Loss: 2.0585
# Epoch [17/20], Step [85/94], Loss: 2.0915
# Epoch [17/20], Step [90/94], Loss: 1.8787
# Epoch [18/20], Step [0/94], Loss: 1.6422
# Epoch [18/20], Step [5/94], Loss: 1.8743
# Epoch [18/20], Step [10/94], Loss: 1.5439
# Epoch [18/20], Step [15/94], Loss: 1.9694
# Epoch [18/20], Step [20/94], Loss: 1.7234
# Epoch [18/20], Step [25/94], Loss: 1.8348
# Epoch [18/20], Step [30/94], Loss: 1.7728
# Epoch [18/20], Step [35/94], Loss: 1.9111
# Epoch [18/20], Step [40/94], Loss: 1.5843
# Epoch [18/20], Step [45/94], Loss: 1.6949
# Epoch [18/20], Step [50/94], Loss: 1.6318
# Epoch [18/20], Step [55/94], Loss: 1.8313
# Epoch [18/20], Step [60/94], Loss: 2.0008
# Epoch [18/20], Step [65/94], Loss: 1.5641
# Epoch [18/20], Step [70/94], Loss: 1.5418
# Epoch [18/20], Step [75/94], Loss: 1.6366
# Epoch [18/20], Step [80/94], Loss: 1.4650
# Epoch [18/20], Step [85/94], Loss: 1.7465
# Epoch [18/20], Step [90/94], Loss: 1.3859
# Epoch [19/20], Step [0/94], Loss: 1.1726
# Epoch [19/20], Step [5/94], Loss: 1.8674
# Epoch [19/20], Step [10/94], Loss: 1.7244
# Epoch [19/20], Step [15/94], Loss: 1.7517
# Epoch [19/20], Step [20/94], Loss: 1.3830
# Epoch [19/20], Step [25/94], Loss: 1.3624
# Epoch [19/20], Step [30/94], Loss: 1.6989
# Epoch [19/20], Step [35/94], Loss: 1.5124
# Epoch [19/20], Step [40/94], Loss: 1.4091
# Epoch [19/20], Step [45/94], Loss: 1.5194
# Epoch [19/20], Step [50/94], Loss: 1.8787
# Epoch [19/20], Step [55/94], Loss: 1.4923
# Epoch [19/20], Step [60/94], Loss: 1.6342
# Epoch [19/20], Step [65/94], Loss: 1.5827
# Epoch [19/20], Step [70/94], Loss: 1.7321
# Epoch [19/20], Step [75/94], Loss: 1.8599
# Epoch [19/20], Step [80/94], Loss: 1.6641
# Epoch [19/20], Step [85/94], Loss: 1.8951
# Epoch [19/20], Step [90/94], Loss: 1.9289
# Epoch [20/20], Step [0/94], Loss: 1.5648
# Epoch [20/20], Step [5/94], Loss: 1.2174
# Epoch [20/20], Step [10/94], Loss: 1.6598
# Epoch [20/20], Step [15/94], Loss: 1.6791
# Epoch [20/20], Step [20/94], Loss: 1.4840
# Epoch [20/20], Step [25/94], Loss: 1.6727
# Epoch [20/20], Step [30/94], Loss: 1.6503
# Epoch [20/20], Step [35/94], Loss: 1.7026
# Epoch [20/20], Step [40/94], Loss: 1.6105
# Epoch [20/20], Step [45/94], Loss: 1.6548
# Epoch [20/20], Step [50/94], Loss: 1.6409
# Epoch [20/20], Step [55/94], Loss: 1.7261
# Epoch [20/20], Step [60/94], Loss: 1.2664
# Epoch [20/20], Step [65/94], Loss: 1.5733
# Epoch [20/20], Step [70/94], Loss: 1.7362
# Epoch [20/20], Step [75/94], Loss: 1.4343
# Epoch [20/20], Step [80/94], Loss: 1.6687
# Epoch [20/20], Step [85/94], Loss: 1.5235
# Epoch [20/20], Step [90/94], Loss: 1.4591

# %%
def tensor_to_word_fn(tensor, vocab):
    try:
        return [vocab.idx2word[idx.item()] for idx in tensor if idx.item() not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
    except KeyError as e:
        print(f"KeyError: {e}")
        return ["<unk>"]

# %%
def corpus_bleu_score_fn(references, candidates):
    smooth = SmoothingFunction().method1
    bleu_scores = [sentence_bleu([ref], cand, smoothing_function=smooth) for ref, cand in zip(references, candidates)]
    return sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0

# %%
# Define evaluate_model for encoder-decoder structure
def evaluate_model(desc, encoder, decoder, data_loader, vocab, bleu_score_fn, tensor_to_word_fn, loss_fn=None):
    encoder.eval()
    decoder.eval()
    total_loss = 0
    references, candidates = [], []

    with torch.no_grad():
        for images, captions in tqdm(data_loader, desc=desc, leave=False):
            images = images.to(device)
            captions = captions.to(device)
            features = encoder(images)
            outputs = decoder.sample(features)

            if loss_fn:
                outputs = decoder(features, captions)
                loss = loss_fn(outputs.view(-1, outputs.size(2)), captions.view(-1))
                total_loss += loss.item()

            for i in range(len(captions)):
                ref = tensor_to_word_fn(captions[i], vocab)
                cand = tensor_to_word_fn(outputs[i], vocab)
                references.append(ref)
                candidates.append(cand)

    avg_loss = total_loss / len(data_loader) if loss_fn else 0
    bleu_score = bleu_score_fn(references, candidates)

    print(f'{desc} Avg Loss: {avg_loss:.4f} BLEU: {bleu_score:.4f}')

    return bleu_score

# %%
# Define evaluate
def evaluate(encoder, decoder, loader):
    encoder.eval()
    decoder.eval()
    smooth = SmoothingFunction().method1
    total_bleu1, total_bleu2, total_bleu3, total_bleu4 = 0, 0, 0, 0
    count = 0
    with torch.no_grad():
        for images, captions in tqdm(loader, desc='Evaluation', leave=False):
            images = images.to(device)
            captions = captions.to(device)
            features = encoder(images)
            outputs = decoder.sample(features)

            for i, output in enumerate(outputs):
                reference = [vocab.idx2word[idx] for idx in captions[i].tolist() if idx not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                candidate = [vocab.idx2word[idx.item()] for idx in output if idx.item() not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                reference = [reference]  # BLEU expects a list of reference lists
                total_bleu1 += sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=smooth)
                total_bleu2 += sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=smooth)
                total_bleu3 += sentence_bleu(reference, candidate, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smooth)
                total_bleu4 += sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smooth)
                count += 1

    return total_bleu1/count, total_bleu2/count, total_bleu3/count, total_bleu4/count

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from tqdm import tqdm

# %%
# Main evaluation logic
with torch.no_grad():
    encoder.eval()
    decoder.eval()

    # Train BLEU
    train_bleu = evaluate_model(
        desc='Train: ',
        encoder=encoder,
        decoder=decoder,
        data_loader=train_loader,
        vocab=vocab,
        bleu_score_fn=corpus_bleu_score_fn,
        tensor_to_word_fn=tensor_to_word_fn,
        loss_fn=None  # Replace with actual loss function if needed
    )

    # Validation BLEU
    val_bleu = evaluate_model(
        desc='Val: ',
        encoder=encoder,
        decoder=decoder,
        data_loader=val_loader,
        vocab=vocab,
        bleu_score_fn=corpus_bleu_score_fn,
        tensor_to_word_fn=tensor_to_word_fn,
        loss_fn=None  # Replace with actual loss function if needed
    )

    # Test BLEU
    test_bleu = evaluate_model(
        desc='Test: ',
        encoder=encoder,
        decoder=decoder,
        data_loader=test_loader,
        vocab=vocab,
        bleu_score_fn=corpus_bleu_score_fn,
        tensor_to_word_fn=tensor_to_word_fn,
        loss_fn=None  # Replace with actual loss function if needed
    )

    for setname, result in zip(('train', 'val', 'test'), (train_bleu, val_bleu, test_bleu)):
        print(f"{setname} Bleu-1: {result:.4f} Bleu-2: {result:.4f} Bleu-3: {result:.4f} Bleu-4: {result:.4f}")
# Out:
# Train:  Avg Loss: 0.0000 BLEU: 0.0203
# Val:  Avg Loss: 0.0000 BLEU: 0.0180
# Test:  Avg Loss: 0.0000 BLEU: 0.0183
# train Bleu-1: 0.0203 Bleu-2: 0.0203 Bleu-3: 0.0203 Bleu-4: 0.0203
# val Bleu-1: 0.0180 Bleu-2: 0.0180 Bleu-3: 0.0180 Bleu-4: 0.0180
# test Bleu-1: 0.0183 Bleu-2: 0.0183 Bleu-3: 0.0183 Bleu-4: 0.0183

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def evaluate(encoder, decoder, loader):
    encoder.eval()
    decoder.eval()
    smooth = SmoothingFunction().method1
    total_bleu1, total_bleu2, total_bleu3, total_bleu4 = 0, 0, 0, 0
    count = 0
    with torch.no_grad():
        for images, captions in loader:
            images = images.to(device)
            captions = captions.to(device)
            features = encoder(images)
            outputs = decoder.sample(features)

            for i, output in enumerate(outputs):
                reference = [vocab.idx2word[idx] for idx in captions[i].tolist() if idx not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                candidate = [vocab.idx2word[idx.item()] for idx in output if idx.item() not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                reference = [reference]  # BLEU expects a list of reference lists
                total_bleu1 += sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=smooth)
                total_bleu2 += sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=smooth)
                total_bleu3 += sentence_bleu(reference, candidate, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smooth)
                total_bleu4 += sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smooth)
                count += 1

    return total_bleu1/count, total_bleu2/count, total_bleu3/count, total_bleu4/count

# %%
# Evaluation
bleu1, bleu2, bleu3, bleu4 = evaluate(encoder, decoder, test_loader)
print(f'BLEU-1: {bleu1:.4f}, BLEU-2: {bleu2:.4f}, BLEU-3: {bleu3:.4f}, BLEU-4: {bleu4:.4f}')
# Out:
# BLEU-1: 0.1438, BLEU-2: 0.0344, BLEU-3: 0.0228, BLEU-4: 0.0191

# %%
all_images, all_captions = generate_captions(encoder, decoder, test_loader, vocab)

# Visualize the captions
visualize_captions(all_images, all_captions, num_samples=5)
# Out:
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
