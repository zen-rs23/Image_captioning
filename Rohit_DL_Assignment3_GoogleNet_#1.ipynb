# %%
# Connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import json
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from collections import Counter
from tqdm.notebook import tqdm
import random
import warnings

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from nltk.translate.bleu_score import sentence_bleu
import torchvision.transforms.functional as F

# %%
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
import zipfile

# Unzipping Flickr8k_Dataset.zip
with zipfile.ZipFile('/content/drive/MyDrive/Flickr8k_Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Flickr8k_Dataset')

# Unzipping Flickr8k_text.zip
with zipfile.ZipFile('/content/drive/MyDrive/Flickr8k_text.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Flickr8k_text')

# %%
# Paths
image_dir = '/content/Flickr8k_Dataset/Flicker8k_Dataset'
annotations_file = '/content/Flickr8k_text/Flickr8k.token.txt'
train_file = '/content/Flickr8k_text/Flickr_8k.trainImages.txt'
val_file = '/content/Flickr8k_text/Flickr_8k.devImages.txt'
test_file = '/content/Flickr8k_text/Flickr_8k.testImages.txt'

# Read annotations
with open(annotations_file, 'r') as f:
    annotations = f.readlines()

# Create a dictionary for image captions
captions_dict = {}
for line in annotations:
    img_name, caption = line.strip().split('\t')
    img_name = img_name.split('#')[0]
    if img_name not in captions_dict:
        captions_dict[img_name] = []
    captions_dict[img_name].append(caption)

# Load train, val, and test image names
def load_image_names(file_path):
    with open(file_path, 'r') as f:
        return f.read().strip().split('\n')

train_img_names = load_image_names(train_file)
val_img_names = load_image_names(val_file)
test_img_names = load_image_names(test_file)

# %%
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def __call__(self, word):
        return self.word2idx.get(word, self.word2idx['<unk>'])

    def __len__(self):
        return len(self.word2idx)

# %%
# Initialize vocabulary
vocab = Vocabulary()

# Add special tokens
special_tokens = ['<pad>', '<start>', '<end>', '<unk>']
for token in special_tokens:
    vocab.add_word(token)

# Tokenize and add words to the vocabulary
for img_name, captions in captions_dict.items():
    for caption in captions:
        tokens = caption.split()  # Simple whitespace tokenizer
        for token in tokens:
            vocab.add_word(token)

print(f"Vocabulary size: {len(vocab)}")
# Out:
# Vocabulary size: 9634

# %%
# Sample a percentage of the training and validation data
def sample_data(img_names, percentage):
    sample_size = int(len(img_names) * percentage)
    return random.sample(img_names, sample_size)

train_img_names_sampled = sample_data(train_img_names, 0.5)  # Sample 50% of images for training
val_img_names_sampled = sample_data(val_img_names, 0.5)  # Sample 50% of images for validation

# Use the full dataset
#train_img_names_sampled = train_img_names  # Use all images for training
#val_img_names_sampled = val_img_names  # Use all images for validation

# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Define collate_fn function
def collate_fn(data):
    images, captions = zip(*data)
    images = torch.stack(images, 0)

    # Tokenize captions and convert to indices
    tokenizer = lambda x: x.split()  # Simple whitespace tokenizer
    captions = [[vocab(token) for token in tokenizer(caption)] for caption in captions]

    # Find the length of the longest caption
    max_len = max(len(caption) for caption in captions)

    # Pad all captions to the same length
    padded_captions = []
    for caption in captions:
        padded_caption = caption + [vocab('<pad>')] * (max_len - len(caption))
        padded_captions.append(padded_caption)

    # Convert to tensor
    captions = torch.tensor(padded_captions)

    return images, captions

class Flickr8kDataset(Dataset):
    def __init__(self, img_names, captions_dict, img_dir, transform=None):
        self.img_names = img_names
        self.captions_dict = captions_dict
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_name = self.img_names[idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        caption = random.choice(self.captions_dict[img_name])  # Choose a random caption for the image
        return image, caption

# Create dataset objects
train_dataset = Flickr8kDataset(train_img_names_sampled, captions_dict, image_dir, transform)
val_dataset = Flickr8kDataset(val_img_names_sampled, captions_dict, image_dir, transform)
test_dataset = Flickr8kDataset(test_img_names, captions_dict, image_dir, transform)

# Create data loaders with collate_fn
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, collate_fn=collate_fn)

# %%
# Check if GPU is available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class EncoderCNN(nn.Module):
    def __init__(self, embed_size):
        super(EncoderCNN, self).__init__()
        googlenet = models.googlenet(pretrained=True)
        for param in googlenet.parameters():
            param.requires_grad = False
        self.googlenet = nn.Sequential(*list(googlenet.children())[:-2])
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.linear = nn.Linear(googlenet.fc.in_features, embed_size)
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.01)

    def forward(self, images):
        features = self.googlenet(images)
        features = self.adaptive_pool(features).reshape(features.size(0), -1)
        features = self.bn(self.linear(features))
        return features


class DecoderRNN(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers=1):
        super(DecoderRNN, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, features, captions):
        embeddings = self.embed(captions)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)
        hiddens, _ = self.lstm(embeddings)
        outputs = self.linear(hiddens)
        return outputs

    def sample(self, features, states=None, max_len=20):
        """Generate captions for given image features using greedy search."""
        sampled_ids = []
        inputs = features.unsqueeze(1)
        batch_size = features.size(0)
        for i in range(max_len):
            hiddens, states = self.lstm(inputs, states)  # hiddens: (batch_size, 1, hidden_size)
            outputs = self.linear(hiddens.squeeze(1))  # outputs: (batch_size, vocab_size)
            _, predicted = outputs.max(1)  # predicted: (batch_size)
            sampled_ids.append(predicted)
            inputs = self.embed(predicted)  # inputs: (batch_size, embed_size)
            inputs = inputs.unsqueeze(1)  # inputs: (batch_size, 1, embed_size)
            if (predicted == vocab('<end>')).all():  # Stop if all predictions in the batch are <end>
                break
        sampled_ids = torch.stack(sampled_ids, 1)  # sampled_ids: (batch_size, max_seq_length)
        return sampled_ids

# Instantiate encoder and decoder
embed_size = 256
hidden_size = 512
vocab_size = len(vocab)  # Update based on your vocabulary size

encoder = EncoderCNN(embed_size).to(device)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size).to(device)

# %%
def generate_captions(encoder, decoder, data_loader, vocab, max_length=20):
    encoder.eval()
    decoder.eval()
    all_images = []
    all_captions = []

    with torch.no_grad():
        for images, _ in data_loader:
            images = images.to(device)
            features = encoder(images)
            sampled_ids = decoder.sample(features, max_len=max_length)
            sampled_ids = sampled_ids.cpu().numpy()

            for i, image in enumerate(images):
                all_images.append(image.cpu())
                caption = []
                for word_id in sampled_ids[i]:
                    word = vocab.idx2word[word_id]
                    if word == '<end>':
                        break
                    if word != '<pad>':
                        caption.append(word)
                caption = ' '.join(caption)
                all_captions.append(caption)

    return all_images, all_captions

def visualize_captions(images, captions, num_samples=5):
    num_samples = min(num_samples, len(images))  # Ensure num_samples does not exceed available images
    plt.figure(figsize=(15, 15))

    for i in range(num_samples):
        plt.subplot((num_samples + 1) // 2, 2, i + 1)
        image = images[i]
        if isinstance(image, torch.Tensor):
            print(f"Original image shape: {image.shape}")
            image = image.permute(1, 2, 0)  # Change from (C, H, W) to (H, W, C)
            print(f"Permuted image shape: {image.shape}")
            image = image.numpy()
            print(f"Numpy image shape: {image.shape}")
            image = transforms.ToPILImage()(image)
            print(f"Converted image type: {type(image)}")
        plt.imshow(image)
        plt.title(captions[i])
        plt.axis('off')
    plt.show()

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.bn.parameters())
optimizer = optim.Adam(params, lr=0.001)

# %%
# Training loop
num_epochs = 20
log_step = 5

for epoch in range(num_epochs):
    encoder.train()
    decoder.train()
    for i, (images, captions) in enumerate(train_loader):
        images = images.to(device)
        captions = captions.to(device)

        features = encoder(images)
        outputs = decoder(features, captions)

        batch_size, sequence_length, _ = outputs.shape
        targets = captions[:, 1:]

        if targets.shape[1] < sequence_length:
            padding = torch.full((batch_size, sequence_length - targets.shape[1]), vocab('<pad>')).to(device)
            targets = torch.cat((targets, padding), dim=1)
        elif targets.shape[1] > sequence_length:
            targets = targets[:, :sequence_length]

        loss = criterion(outputs.view(batch_size * sequence_length, -1), targets.reshape(-1))

        decoder.zero_grad()
        encoder.zero_grad()
        loss.backward()
        optimizer.step()

        if i % log_step == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i}/{len(train_loader)}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/20], Step [0/94], Loss: 9.0942
# Epoch [1/20], Step [5/94], Loss: 5.2920
# Epoch [1/20], Step [10/94], Loss: 5.3280
# Epoch [1/20], Step [15/94], Loss: 4.5664
# Epoch [1/20], Step [20/94], Loss: 2.9449
# Epoch [1/20], Step [25/94], Loss: 3.4104
# Epoch [1/20], Step [30/94], Loss: 3.0583
# Epoch [1/20], Step [35/94], Loss: 2.8749
# Epoch [1/20], Step [40/94], Loss: 2.5330
# Epoch [1/20], Step [45/94], Loss: 2.9912
# Epoch [1/20], Step [50/94], Loss: 2.2695
# Epoch [1/20], Step [55/94], Loss: 2.3971
# Epoch [1/20], Step [60/94], Loss: 2.9775
# Epoch [1/20], Step [65/94], Loss: 2.9850
# Epoch [1/20], Step [70/94], Loss: 2.9361
# Epoch [1/20], Step [75/94], Loss: 3.1092
# Epoch [1/20], Step [80/94], Loss: 2.4961
# Epoch [1/20], Step [85/94], Loss: 3.0600
# Epoch [1/20], Step [90/94], Loss: 2.9677
# Epoch [2/20], Step [0/94], Loss: 2.8447
# Epoch [2/20], Step [5/94], Loss: 2.5833
# Epoch [2/20], Step [10/94], Loss: 1.7901
# Epoch [2/20], Step [15/94], Loss: 2.9126
# Epoch [2/20], Step [20/94], Loss: 3.1450
# Epoch [2/20], Step [25/94], Loss: 2.6258
# Epoch [2/20], Step [30/94], Loss: 2.9309
# Epoch [2/20], Step [35/94], Loss: 1.8867
# Epoch [2/20], Step [40/94], Loss: 2.5107
# Epoch [2/20], Step [45/94], Loss: 2.0463
# Epoch [2/20], Step [50/94], Loss: 2.6197
# Epoch [2/20], Step [55/94], Loss: 3.0415
# Epoch [2/20], Step [60/94], Loss: 3.0171
# Epoch [2/20], Step [65/94], Loss: 2.8159
# Epoch [2/20], Step [70/94], Loss: 3.0953
# Epoch [2/20], Step [75/94], Loss: 2.6553
# Epoch [2/20], Step [80/94], Loss: 2.7899
# Epoch [2/20], Step [85/94], Loss: 2.2372
# Epoch [2/20], Step [90/94], Loss: 2.5302
# Epoch [3/20], Step [0/94], Loss: 2.3376
# Epoch [3/20], Step [5/94], Loss: 2.4725
# Epoch [3/20], Step [10/94], Loss: 2.6109
# Epoch [3/20], Step [15/94], Loss: 2.8986
# Epoch [3/20], Step [20/94], Loss: 2.8714
# Epoch [3/20], Step [25/94], Loss: 2.0656
# Epoch [3/20], Step [30/94], Loss: 2.5784
# Epoch [3/20], Step [35/94], Loss: 2.7220
# Epoch [3/20], Step [40/94], Loss: 2.0333
# Epoch [3/20], Step [45/94], Loss: 2.2674
# Epoch [3/20], Step [50/94], Loss: 1.8553
# Epoch [3/20], Step [55/94], Loss: 2.5934
# Epoch [3/20], Step [60/94], Loss: 2.7974
# Epoch [3/20], Step [65/94], Loss: 2.5734
# Epoch [3/20], Step [70/94], Loss: 2.7456
# Epoch [3/20], Step [75/94], Loss: 2.2272
# Epoch [3/20], Step [80/94], Loss: 2.6841
# Epoch [3/20], Step [85/94], Loss: 1.9771
# Epoch [3/20], Step [90/94], Loss: 2.5103
# Epoch [4/20], Step [0/94], Loss: 2.8308
# Epoch [4/20], Step [5/94], Loss: 2.5957
# Epoch [4/20], Step [10/94], Loss: 2.4022
# Epoch [4/20], Step [15/94], Loss: 2.1809
# Epoch [4/20], Step [20/94], Loss: 1.9062
# Epoch [4/20], Step [25/94], Loss: 1.9994
# Epoch [4/20], Step [30/94], Loss: 2.3378
# Epoch [4/20], Step [35/94], Loss: 2.4527
# Epoch [4/20], Step [40/94], Loss: 2.2510
# Epoch [4/20], Step [45/94], Loss: 2.0502
# Epoch [4/20], Step [50/94], Loss: 1.9078
# Epoch [4/20], Step [55/94], Loss: 2.6755
# Epoch [4/20], Step [60/94], Loss: 1.8899
# Epoch [4/20], Step [65/94], Loss: 2.6629
# Epoch [4/20], Step [70/94], Loss: 2.1233
# Epoch [4/20], Step [75/94], Loss: 2.0359
# Epoch [4/20], Step [80/94], Loss: 2.0527
# Epoch [4/20], Step [85/94], Loss: 2.3183
# Epoch [4/20], Step [90/94], Loss: 2.3797
# Epoch [5/20], Step [0/94], Loss: 2.1412
# Epoch [5/20], Step [5/94], Loss: 2.6930
# Epoch [5/20], Step [10/94], Loss: 1.9597
# Epoch [5/20], Step [15/94], Loss: 1.9520
# Epoch [5/20], Step [20/94], Loss: 2.4663
# Epoch [5/20], Step [25/94], Loss: 2.1665
# Epoch [5/20], Step [30/94], Loss: 2.6603
# Epoch [5/20], Step [35/94], Loss: 2.4922
# Epoch [5/20], Step [40/94], Loss: 2.3005
# Epoch [5/20], Step [45/94], Loss: 2.1673
# Epoch [5/20], Step [50/94], Loss: 2.3601
# Epoch [5/20], Step [55/94], Loss: 2.3671
# Epoch [5/20], Step [60/94], Loss: 2.1407
# Epoch [5/20], Step [65/94], Loss: 2.4977
# Epoch [5/20], Step [70/94], Loss: 2.4280
# Epoch [5/20], Step [75/94], Loss: 2.2153
# Epoch [5/20], Step [80/94], Loss: 2.4679
# Epoch [5/20], Step [85/94], Loss: 2.1493
# Epoch [5/20], Step [90/94], Loss: 2.3203
# Epoch [6/20], Step [0/94], Loss: 2.3096
# Epoch [6/20], Step [5/94], Loss: 2.4584
# Epoch [6/20], Step [10/94], Loss: 2.0590
# Epoch [6/20], Step [15/94], Loss: 2.2194
# Epoch [6/20], Step [20/94], Loss: 1.9335
# Epoch [6/20], Step [25/94], Loss: 2.5285
# Epoch [6/20], Step [30/94], Loss: 2.0772
# Epoch [6/20], Step [35/94], Loss: 2.3813
# Epoch [6/20], Step [40/94], Loss: 2.1302
# Epoch [6/20], Step [45/94], Loss: 2.4983
# Epoch [6/20], Step [50/94], Loss: 2.1058
# Epoch [6/20], Step [55/94], Loss: 2.1766
# Epoch [6/20], Step [60/94], Loss: 2.2108
# Epoch [6/20], Step [65/94], Loss: 2.2911
# Epoch [6/20], Step [70/94], Loss: 1.8418
# Epoch [6/20], Step [75/94], Loss: 2.2798
# Epoch [6/20], Step [80/94], Loss: 2.2405
# Epoch [6/20], Step [85/94], Loss: 2.1058
# Epoch [6/20], Step [90/94], Loss: 1.8461
# Epoch [7/20], Step [0/94], Loss: 2.2000
# Epoch [7/20], Step [5/94], Loss: 1.8305
# Epoch [7/20], Step [10/94], Loss: 2.1905
# Epoch [7/20], Step [15/94], Loss: 2.0487
# Epoch [7/20], Step [20/94], Loss: 1.9848
# Epoch [7/20], Step [25/94], Loss: 1.8587
# Epoch [7/20], Step [30/94], Loss: 2.0827
# Epoch [7/20], Step [35/94], Loss: 2.1032
# Epoch [7/20], Step [40/94], Loss: 2.3824
# Epoch [7/20], Step [45/94], Loss: 2.1423
# Epoch [7/20], Step [50/94], Loss: 2.6905
# Epoch [7/20], Step [55/94], Loss: 2.2391
# Epoch [7/20], Step [60/94], Loss: 1.5505
# Epoch [7/20], Step [65/94], Loss: 2.1902
# Epoch [7/20], Step [70/94], Loss: 1.5229
# Epoch [7/20], Step [75/94], Loss: 2.2427
# Epoch [7/20], Step [80/94], Loss: 1.9419
# Epoch [7/20], Step [85/94], Loss: 2.3945
# Epoch [7/20], Step [90/94], Loss: 2.2703
# Epoch [8/20], Step [0/94], Loss: 2.0490
# Epoch [8/20], Step [5/94], Loss: 1.7447
# Epoch [8/20], Step [10/94], Loss: 2.4501
# Epoch [8/20], Step [15/94], Loss: 2.0886
# Epoch [8/20], Step [20/94], Loss: 1.6013
# Epoch [8/20], Step [25/94], Loss: 1.7858
# Epoch [8/20], Step [30/94], Loss: 2.2095
# Epoch [8/20], Step [35/94], Loss: 2.1296
# Epoch [8/20], Step [40/94], Loss: 1.4122
# Epoch [8/20], Step [45/94], Loss: 1.9419
# Epoch [8/20], Step [50/94], Loss: 2.2864
# Epoch [8/20], Step [55/94], Loss: 2.3361
# Epoch [8/20], Step [60/94], Loss: 1.8333
# Epoch [8/20], Step [65/94], Loss: 1.9635
# Epoch [8/20], Step [70/94], Loss: 2.3492
# Epoch [8/20], Step [75/94], Loss: 1.7288
# Epoch [8/20], Step [80/94], Loss: 2.2002
# Epoch [8/20], Step [85/94], Loss: 1.9333
# Epoch [8/20], Step [90/94], Loss: 2.2580
# Epoch [9/20], Step [0/94], Loss: 1.5975
# Epoch [9/20], Step [5/94], Loss: 2.2050
# Epoch [9/20], Step [10/94], Loss: 1.8705
# Epoch [9/20], Step [15/94], Loss: 2.4459
# Epoch [9/20], Step [20/94], Loss: 2.0690
# Epoch [9/20], Step [25/94], Loss: 1.9696
# Epoch [9/20], Step [30/94], Loss: 2.0777
# Epoch [9/20], Step [35/94], Loss: 2.2590
# Epoch [9/20], Step [40/94], Loss: 1.7807
# Epoch [9/20], Step [45/94], Loss: 1.9074
# Epoch [9/20], Step [50/94], Loss: 2.2412
# Epoch [9/20], Step [55/94], Loss: 2.1879
# Epoch [9/20], Step [60/94], Loss: 1.9833
# Epoch [9/20], Step [65/94], Loss: 1.7024
# Epoch [9/20], Step [70/94], Loss: 2.0709
# Epoch [9/20], Step [75/94], Loss: 2.2199
# Epoch [9/20], Step [80/94], Loss: 2.2603
# Epoch [9/20], Step [85/94], Loss: 2.4401
# Epoch [9/20], Step [90/94], Loss: 1.6641
# Epoch [10/20], Step [0/94], Loss: 1.8031
# Epoch [10/20], Step [5/94], Loss: 1.7518
# Epoch [10/20], Step [10/94], Loss: 2.1082
# Epoch [10/20], Step [15/94], Loss: 2.2714
# Epoch [10/20], Step [20/94], Loss: 2.1217
# Epoch [10/20], Step [25/94], Loss: 2.2501
# Epoch [10/20], Step [30/94], Loss: 1.7790
# Epoch [10/20], Step [35/94], Loss: 2.2649
# Epoch [10/20], Step [40/94], Loss: 1.7904
# Epoch [10/20], Step [45/94], Loss: 1.7187
# Epoch [10/20], Step [50/94], Loss: 2.2254
# Epoch [10/20], Step [55/94], Loss: 2.0753
# Epoch [10/20], Step [60/94], Loss: 2.1094
# Epoch [10/20], Step [65/94], Loss: 2.0435
# Epoch [10/20], Step [70/94], Loss: 1.9171
# Epoch [10/20], Step [75/94], Loss: 1.9542
# Epoch [10/20], Step [80/94], Loss: 1.6981
# Epoch [10/20], Step [85/94], Loss: 2.0125
# Epoch [10/20], Step [90/94], Loss: 2.4398
# Epoch [11/20], Step [0/94], Loss: 1.3082
# Epoch [11/20], Step [5/94], Loss: 2.2281
# Epoch [11/20], Step [10/94], Loss: 2.0197
# Epoch [11/20], Step [15/94], Loss: 2.2792
# Epoch [11/20], Step [20/94], Loss: 2.0490
# Epoch [11/20], Step [25/94], Loss: 2.0155
# Epoch [11/20], Step [30/94], Loss: 1.8815
# Epoch [11/20], Step [35/94], Loss: 1.8786
# Epoch [11/20], Step [40/94], Loss: 1.7411
# Epoch [11/20], Step [45/94], Loss: 2.2215
# Epoch [11/20], Step [50/94], Loss: 1.9947
# Epoch [11/20], Step [55/94], Loss: 1.8453
# Epoch [11/20], Step [60/94], Loss: 1.6338
# Epoch [11/20], Step [65/94], Loss: 1.5973
# Epoch [11/20], Step [70/94], Loss: 1.9366
# Epoch [11/20], Step [75/94], Loss: 1.4065
# Epoch [11/20], Step [80/94], Loss: 1.2636
# Epoch [11/20], Step [85/94], Loss: 1.6244
# Epoch [11/20], Step [90/94], Loss: 1.8118
# Epoch [12/20], Step [0/94], Loss: 2.0756
# Epoch [12/20], Step [5/94], Loss: 1.5766
# Epoch [12/20], Step [10/94], Loss: 1.4853
# Epoch [12/20], Step [15/94], Loss: 1.9662
# Epoch [12/20], Step [20/94], Loss: 2.2422
# Epoch [12/20], Step [25/94], Loss: 1.8656
# Epoch [12/20], Step [30/94], Loss: 1.5524
# Epoch [12/20], Step [35/94], Loss: 1.8202
# Epoch [12/20], Step [40/94], Loss: 1.9181
# Epoch [12/20], Step [45/94], Loss: 1.6577
# Epoch [12/20], Step [50/94], Loss: 2.0122
# Epoch [12/20], Step [55/94], Loss: 1.9169
# Epoch [12/20], Step [60/94], Loss: 2.0655
# Epoch [12/20], Step [65/94], Loss: 2.0221
# Epoch [12/20], Step [70/94], Loss: 1.6301
# Epoch [12/20], Step [75/94], Loss: 1.8492
# Epoch [12/20], Step [80/94], Loss: 1.9978
# Epoch [12/20], Step [85/94], Loss: 1.9400
# Epoch [12/20], Step [90/94], Loss: 1.9982
# Epoch [13/20], Step [0/94], Loss: 1.4295
# Epoch [13/20], Step [5/94], Loss: 1.4785
# Epoch [13/20], Step [10/94], Loss: 1.8818
# Epoch [13/20], Step [15/94], Loss: 1.9236
# Epoch [13/20], Step [20/94], Loss: 1.7112
# Epoch [13/20], Step [25/94], Loss: 2.0320
# Epoch [13/20], Step [30/94], Loss: 1.5970
# Epoch [13/20], Step [35/94], Loss: 1.9940
# Epoch [13/20], Step [40/94], Loss: 2.0655
# Epoch [13/20], Step [45/94], Loss: 2.3572
# Epoch [13/20], Step [50/94], Loss: 1.5620
# Epoch [13/20], Step [55/94], Loss: 1.6792
# Epoch [13/20], Step [60/94], Loss: 2.3924
# Epoch [13/20], Step [65/94], Loss: 1.8833
# Epoch [13/20], Step [70/94], Loss: 2.4098
# Epoch [13/20], Step [75/94], Loss: 1.2658
# Epoch [13/20], Step [80/94], Loss: 1.8960
# Epoch [13/20], Step [85/94], Loss: 1.9393
# Epoch [13/20], Step [90/94], Loss: 2.1843
# Epoch [14/20], Step [0/94], Loss: 2.1047
# Epoch [14/20], Step [5/94], Loss: 1.5150
# Epoch [14/20], Step [10/94], Loss: 1.7512
# Epoch [14/20], Step [15/94], Loss: 1.7154
# Epoch [14/20], Step [20/94], Loss: 1.5981
# Epoch [14/20], Step [25/94], Loss: 1.7463
# Epoch [14/20], Step [30/94], Loss: 1.1971
# Epoch [14/20], Step [35/94], Loss: 2.1046
# Epoch [14/20], Step [40/94], Loss: 2.0055
# Epoch [14/20], Step [45/94], Loss: 1.5189
# Epoch [14/20], Step [50/94], Loss: 1.7260
# Epoch [14/20], Step [55/94], Loss: 1.9671
# Epoch [14/20], Step [60/94], Loss: 2.1645
# Epoch [14/20], Step [65/94], Loss: 1.9930
# Epoch [14/20], Step [70/94], Loss: 1.6397
# Epoch [14/20], Step [75/94], Loss: 1.9491
# Epoch [14/20], Step [80/94], Loss: 2.1191
# Epoch [14/20], Step [85/94], Loss: 1.9256
# Epoch [14/20], Step [90/94], Loss: 1.5427
# Epoch [15/20], Step [0/94], Loss: 2.0038
# Epoch [15/20], Step [5/94], Loss: 1.9499
# Epoch [15/20], Step [10/94], Loss: 1.6988
# Epoch [15/20], Step [15/94], Loss: 1.7933
# Epoch [15/20], Step [20/94], Loss: 2.1430
# Epoch [15/20], Step [25/94], Loss: 2.0988
# Epoch [15/20], Step [30/94], Loss: 1.4987
# Epoch [15/20], Step [35/94], Loss: 1.7480
# Epoch [15/20], Step [40/94], Loss: 1.7793
# Epoch [15/20], Step [45/94], Loss: 1.9335
# Epoch [15/20], Step [50/94], Loss: 1.9736
# Epoch [15/20], Step [55/94], Loss: 1.5056
# Epoch [15/20], Step [60/94], Loss: 1.8116
# Epoch [15/20], Step [65/94], Loss: 1.7462
# Epoch [15/20], Step [70/94], Loss: 1.5758
# Epoch [15/20], Step [75/94], Loss: 2.0809
# Epoch [15/20], Step [80/94], Loss: 1.8507
# Epoch [15/20], Step [85/94], Loss: 2.3598
# Epoch [15/20], Step [90/94], Loss: 1.6519
# Epoch [16/20], Step [0/94], Loss: 2.1182
# Epoch [16/20], Step [5/94], Loss: 1.3700
# Epoch [16/20], Step [10/94], Loss: 1.6119
# Epoch [16/20], Step [15/94], Loss: 1.3027
# Epoch [16/20], Step [20/94], Loss: 1.4336
# Epoch [16/20], Step [25/94], Loss: 1.9256
# Epoch [16/20], Step [30/94], Loss: 1.5655
# Epoch [16/20], Step [35/94], Loss: 1.7624
# Epoch [16/20], Step [40/94], Loss: 1.7813
# Epoch [16/20], Step [45/94], Loss: 1.2424
# Epoch [16/20], Step [50/94], Loss: 1.2783
# Epoch [16/20], Step [55/94], Loss: 1.4821
# Epoch [16/20], Step [60/94], Loss: 1.5253
# Epoch [16/20], Step [65/94], Loss: 1.8635
# Epoch [16/20], Step [70/94], Loss: 1.1796
# Epoch [16/20], Step [75/94], Loss: 1.7402
# Epoch [16/20], Step [80/94], Loss: 1.5439
# Epoch [16/20], Step [85/94], Loss: 1.6353
# Epoch [16/20], Step [90/94], Loss: 1.8213
# Epoch [17/20], Step [0/94], Loss: 1.6102
# Epoch [17/20], Step [5/94], Loss: 2.2449
# Epoch [17/20], Step [10/94], Loss: 1.2672
# Epoch [17/20], Step [15/94], Loss: 1.7406
# Epoch [17/20], Step [20/94], Loss: 1.5215
# Epoch [17/20], Step [25/94], Loss: 1.6743
# Epoch [17/20], Step [30/94], Loss: 1.9964
# Epoch [17/20], Step [35/94], Loss: 1.5239
# Epoch [17/20], Step [40/94], Loss: 2.0505
# Epoch [17/20], Step [45/94], Loss: 1.5941
# Epoch [17/20], Step [50/94], Loss: 1.5714
# Epoch [17/20], Step [55/94], Loss: 1.6075
# Epoch [17/20], Step [60/94], Loss: 1.5792
# Epoch [17/20], Step [65/94], Loss: 1.8072
# Epoch [17/20], Step [70/94], Loss: 1.7143
# Epoch [17/20], Step [75/94], Loss: 1.6283
# Epoch [17/20], Step [80/94], Loss: 1.8850
# Epoch [17/20], Step [85/94], Loss: 1.6503
# Epoch [17/20], Step [90/94], Loss: 1.6817
# Epoch [18/20], Step [0/94], Loss: 1.6784
# Epoch [18/20], Step [5/94], Loss: 1.7550
# Epoch [18/20], Step [10/94], Loss: 2.0342
# Epoch [18/20], Step [15/94], Loss: 1.6896
# Epoch [18/20], Step [20/94], Loss: 1.6713
# Epoch [18/20], Step [25/94], Loss: 1.6123
# Epoch [18/20], Step [30/94], Loss: 1.7765
# Epoch [18/20], Step [35/94], Loss: 1.6630
# Epoch [18/20], Step [40/94], Loss: 1.9450
# Epoch [18/20], Step [45/94], Loss: 1.9552
# Epoch [18/20], Step [50/94], Loss: 1.2564
# Epoch [18/20], Step [55/94], Loss: 1.9324
# Epoch [18/20], Step [60/94], Loss: 1.9744
# Epoch [18/20], Step [65/94], Loss: 2.1478
# Epoch [18/20], Step [70/94], Loss: 2.0963
# Epoch [18/20], Step [75/94], Loss: 1.8407
# Epoch [18/20], Step [80/94], Loss: 1.4013
# Epoch [18/20], Step [85/94], Loss: 1.8307
# Epoch [18/20], Step [90/94], Loss: 1.3982
# Epoch [19/20], Step [0/94], Loss: 1.9009
# Epoch [19/20], Step [5/94], Loss: 1.7075
# Epoch [19/20], Step [10/94], Loss: 1.7530
# Epoch [19/20], Step [15/94], Loss: 1.3581
# Epoch [19/20], Step [20/94], Loss: 1.7486
# Epoch [19/20], Step [25/94], Loss: 1.4704
# Epoch [19/20], Step [30/94], Loss: 1.6817
# Epoch [19/20], Step [35/94], Loss: 1.0923
# Epoch [19/20], Step [40/94], Loss: 1.9195
# Epoch [19/20], Step [45/94], Loss: 1.2881
# Epoch [19/20], Step [50/94], Loss: 1.4824
# Epoch [19/20], Step [55/94], Loss: 1.5961
# Epoch [19/20], Step [60/94], Loss: 1.7162
# Epoch [19/20], Step [65/94], Loss: 2.0721
# Epoch [19/20], Step [70/94], Loss: 1.5161
# Epoch [19/20], Step [75/94], Loss: 1.5351
# Epoch [19/20], Step [80/94], Loss: 1.5379
# Epoch [19/20], Step [85/94], Loss: 1.6755
# Epoch [19/20], Step [90/94], Loss: 1.3943
# Epoch [20/20], Step [0/94], Loss: 1.4284
# Epoch [20/20], Step [5/94], Loss: 1.8968
# Epoch [20/20], Step [10/94], Loss: 1.6695
# Epoch [20/20], Step [15/94], Loss: 1.3733
# Epoch [20/20], Step [20/94], Loss: 1.5900
# Epoch [20/20], Step [25/94], Loss: 1.6865
# Epoch [20/20], Step [30/94], Loss: 1.7835
# Epoch [20/20], Step [35/94], Loss: 1.6697
# Epoch [20/20], Step [40/94], Loss: 1.5489
# Epoch [20/20], Step [45/94], Loss: 1.5570
# Epoch [20/20], Step [50/94], Loss: 1.2342
# Epoch [20/20], Step [55/94], Loss: 1.7864
# Epoch [20/20], Step [60/94], Loss: 1.5973
# Epoch [20/20], Step [65/94], Loss: 1.7412
# Epoch [20/20], Step [70/94], Loss: 1.6839
# Epoch [20/20], Step [75/94], Loss: 1.3474
# Epoch [20/20], Step [80/94], Loss: 1.7665
# Epoch [20/20], Step [85/94], Loss: 1.5629
# Epoch [20/20], Step [90/94], Loss: 1.7070

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def evaluate(encoder, decoder, loader):
    encoder.eval()
    decoder.eval()
    smooth = SmoothingFunction().method1
    total_bleu1, total_bleu2, total_bleu3, total_bleu4 = 0, 0, 0, 0
    count = 0
    with torch.no_grad():
        for images, captions in loader:
            images = images.to(device)
            captions = captions.to(device)
            features = encoder(images)
            outputs = decoder.sample(features)

            for i, output in enumerate(outputs):
                reference = [vocab.idx2word[idx] for idx in captions[i].tolist() if idx not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                candidate = [vocab.idx2word[idx.item()] for idx in output if idx.item() not in [vocab('<pad>'), vocab('<start>'), vocab('<end>'), vocab('<unk>')]]
                reference = [reference]  # BLEU expects a list of reference lists
                total_bleu1 += sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=smooth)
                total_bleu2 += sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=smooth)
                total_bleu3 += sentence_bleu(reference, candidate, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smooth)
                total_bleu4 += sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smooth)
                count += 1

    return total_bleu1/count, total_bleu2/count, total_bleu3/count, total_bleu4/count

# %%
# Evaluation
bleu1, bleu2, bleu3, bleu4 = evaluate(encoder, decoder, test_loader)
print(f'BLEU-1: {bleu1:.4f}, BLEU-2: {bleu2:.4f}, BLEU-3: {bleu3:.4f}, BLEU-4: {bleu4:.4f}')
# Out:
# BLEU-1: 0.1504, BLEU-2: 0.0341, BLEU-3: 0.0224, BLEU-4: 0.0186

# %%
all_images, all_captions = generate_captions(encoder, decoder, test_loader, vocab)

# Visualize the captions
visualize_captions(all_images, all_captions, num_samples=5)
# Out:
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
# Original image shape: torch.Size([3, 224, 224])
# Permuted image shape: torch.Size([224, 224, 3])
# Numpy image shape: (224, 224, 3)
# Converted image type: <class 'PIL.Image.Image'>
